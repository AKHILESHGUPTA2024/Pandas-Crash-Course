# %% [markdown]
# ### Pandas Quick Tutorial Overview

# %% [markdown]
# ###### Pandas is an open source library used in data extraction, data analytics, data manipulation, data cleaning, data transformations, it contains Series and DataFrame

# %% [markdown]
# ##### Series : like an individual column of a table

# %%
import pandas as pd #pd is the short name of pandas as widely used with this name, hence follow the same naming convention
data = ['apple','banana','pineapple','watermelon','grapes']
Ser1 = pd.Series(data,name='fruits')
Ser2 = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
Ser2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# ##### DataFrame : like a table

# %%
data ={'Name':['John','Maria','Bob','Alex','Suzanne'],
       'Age':[21,33,18,44,20],
       'Income':[100,234,238,832,901]}
dframe = pd.DataFrame(data)
dframe
# Out:
#       Name  Age  Income
# 0     John   21     100
# 1    Maria   33     234
# 2      Bob   18     238
# 3     Alex   44     832
# 4  Suzanne   20     901

# %% [markdown]
# ##### Import a .csv file

# %%
df=pd.read_csv('/Users/A K Gupta/Downloads/telecom_customer_churn.csv')

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
pd.set_option('display.max_columns',50)
df.head() # this will show top 5 rows by default | you can change with any number
df.head(10)
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
# 5  0013-MHZWF  Female   23      No                     3      Midpines
# 6  0013-SMEOE  Female   67     Yes                     0        Lompoc
# 7  0014-BMAQU    Male   52     Yes                     0          Napa
# 8  0015-UOCOJ  Female   68      No                     0   Simi Valley
# 9  0016-QLJIS  Female   43     Yes                     1      Sheridan
#
#    Zip Code   Latitude   Longitude  Number of Referrals  Tenure in Months  \
# 0     93225  34.827662 -118.999073                    2                 9
# ...

# %%
df.tail() # this will show bottom 5 rows by default | you can change with any number
df.tail(7)
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 7036  9985-MWVIX  Female   53      No                     0          Hume
# 7037  9986-BONCE  Female   36      No                     0     Fallbrook
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  Tenure in Months  \
# 7036     93628  36.807595 -118.901544                    0                 1
# 7037     92028  33.362575 -117.299644                    0                 4
# 7038     91941  32.759327 -116.997260                    0                13
# ...

# %%
df.columns # will show all columns of the specified dataframe
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Churn Category', 'Churn Reason'],
#       dtype='object')

# %%
df.info() # will show all the informations related with this dataframe, like column name with their respective datatypes and null or not-null columns with rows numbers, also how much memory this dataframe consumes at the bottom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
#for quick overview of info
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Columns: 38 entries, Customer ID to Churn Reason
# dtypes: float64(9), int64(6), object(23)
# memory usage: 2.0+ MB

# %%
#data types with columns
df.dtypes
# Out:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# City                                  object
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download              float64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# ...

# %%
#shape of a dataframe (showing number of rows, columns)
df.shape
# Out:
# (7043, 38)

# %%
#length of the dataframe (total number of rows)
len(df)
# Out:
# 7043

# %%
#describe will show the statistics of all the numerical columns of the dataframe
df.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %%
# you can also describe some categorical columns as
df[['Gender','Customer ID']].describe()
# Out:
#        Gender Customer ID
# count    7043        7043
# unique      2        7043
# top      Male  0002-ORFBO
# freq     3555           1

# %%
#sub setting columns
df[['Gender','Married']] # taken 2 columns
df[['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
       'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals']] # taken 10 columns
df[df.columns[:5]] # this will show 5 columns start with 0 till 5 rows
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents
# 0     0002-ORFBO  Female   37     Yes                     0
# 1     0003-MKNFE    Male   46      No                     0
# 2     0004-TLHLJ    Male   50      No                     0
# 3     0011-IGKFF    Male   78     Yes                     0
# 4     0013-EXCHZ  Female   75     Yes                     0
# ...          ...     ...  ...     ...                   ...
# 7038  9987-LUTYD  Female   20      No                     0
# 7039  9992-RRAMN    Male   40     Yes                     0
# 7040  9992-UJOEL    Male   22      No                     0
# 7041  9993-LHIEB    Male   21     Yes                     0
# 7042  9995-HOTOH    Male   36     Yes                     0
#
# [7043 rows x 5 columns]

# %%
# taking samples
df.sample(5) # taken 5 rows based on overall dataframe
df.sample(5,random_state=500) # taken 5 rows based on 500 rows of the dataframe
df.sample(frac=0.1) # taken 10% sample based on overall dataframe
df.sample(frac=0.001, random_state=242) # taken a fraction sample based on random 242 rows
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 5670  7994-UYIVZ    Male   62     Yes                     0
# 1425  2100-BDNSN  Female   39     Yes                     0
# 4485  6331-EWIEB    Male   49      No                     0
# 603   0883-EIBTI  Female   23      No                     0
# 1369  2034-CGRHZ    Male   73      No                     0
# 6025  8519-IMDHU    Male   74     Yes                     0
# 3302  4707-YNOQA  Female   57     Yes                     1
#
#                    City  Zip Code   Latitude   Longitude  Number of Referrals  \
# 5670          Miramonte     93641  36.696759 -119.024051                    1
# 1425  Strawberry Valley     95981  39.584580 -121.093256                    1
# 4485           El Monte     91731  34.079934 -118.046695                    0
# 603          Clarksburg     95612  38.384648 -121.578701                    0
# 1369      San Francisco     94104  37.791222 -122.402241                    0
# ...

# %%
# filtering using loc | iloc (loc = for columns & iloc = for rows)
df.loc[df['Gender']=='Male'] # filter only Males
df.loc[(df['Gender']=='Male') & (df['Age']>50)] # filter only Males whose Ages are >50
df.loc[~(df['Gender']=='Male') & (df['Age']>50)] # reverse of the above using ~ sign
df.loc[:,['Customer ID', 'Gender','Married']] # this will show all rows for the specified column names (in this case - 3 columns)

df.iloc[:5]#this will show top 5 rows
df.iloc[100:200] #this will show rows started from 100 till 200
df.iloc[0,5] #this will show 1st row and 5th col value (single value)
df.iloc[:5,:5] # this will show 5 rows start from 0 till 5th and columns start from 0 till 5th
df.iloc[[5]] # this will show only 5th row
df.iloc[:,5] # this will show rows start from 0 till end with only 5th column
# Out:
#      Customer ID  Gender Married
# 0     0002-ORFBO  Female     Yes
# 1     0003-MKNFE    Male      No
# 2     0004-TLHLJ    Male      No
# 3     0011-IGKFF    Male     Yes
# 4     0013-EXCHZ  Female     Yes
# ...          ...     ...     ...
# 7038  9987-LUTYD  Female      No
# 7039  9992-RRAMN    Male     Yes
# 7040  9992-UJOEL    Male      No
# 7041  9993-LHIEB    Male     Yes
# 7042  9995-HOTOH    Male     Yes
#
# [7043 rows x 3 columns]

# %%
#select datatypes
df.select_dtypes('int')#only numerical columns will be displayed, you can change datatypes if you wish to
# Out:
#       Age  Number of Dependents  Zip Code  Number of Referrals  \
# 0      37                     0     93225                    2
# 1      46                     0     91206                    0
# 2      50                     0     92627                    0
# 3      78                     0     94553                    1
# 4      75                     0     93010                    3
# ...   ...                   ...       ...                  ...
# 7038   20                     0     91941                    0
# 7039   40                     0     95367                    1
# 7040   22                     0     95432                    0
# 7041   21                     0     92075                    5
# 7042   36                     0     96125                    1
#
#       Tenure in Months  Total Extra Data Charges
# 0                    9                         0
# 1                    9                        10
# 2                    4                         0
# ...

# %%
#Query
df.query('(Gender=="Male") and Age>50')
# Out:
#      Customer ID Gender  Age Married  Number of Dependents           City  \
# 3     0011-IGKFF   Male   78     Yes                     0       Martinez
# 7     0014-BMAQU   Male   52     Yes                     0           Napa
# 18    0022-TCJCI   Male   79      No                     0      Daly City
# 19    0023-HGHWL   Male   67      No                     0    Morgan Hill
# 28    0042-JVWOJ   Male   64      No                     0     Glen Ellen
# ...          ...    ...  ...     ...                   ...            ...
# 7020  9961-JBNMK   Male   79      No                     0  Desert Center
# 7023  9965-YOKZB   Male   73      No                     0  Grizzly Flats
# 7027  9971-ZWPBF   Male   70     Yes                     1         Orinda
# 7032  9975-GPKZU   Male   62     Yes                     3        Alameda
# 7034  9978-HYCIN   Male   72     Yes                     1    Bakersfield
#
#       Zip Code   Latitude   Longitude  Number of Referrals  Tenure in Months  \
# ...

# %%
# summary statistics
print(df['Age'].min())
print(df['Age'].max())
print(df['Age'].mean())
print(df['Age'].std())
print(df['Age'].sum())
print(df['Age'].quantile(0.5))
print(df['Age'].quantile([0.25,0.75]))
# Out:
# 19
# 80
# 46.50972596904728
# 16.750351655102634
# 327568
# 46.0
# 0.25    32.0
# 0.75    60.0
# Name: Age, dtype: float64

# %%
#aggregations
df[['Age','Tenure in Months','Latitude','Avg Monthly Long Distance Charges','Longitude']].agg(['mean','sum','max','std'])# 1st way
df[['Age','Tenure in Months','Latitude','Avg Monthly Long Distance Charges','Longitude']].agg(                           #2nd way
    {'Age':['mean','sum'],
     'Tenure in Months':['max','min'],
     'Latitude':['max','min'],
     'Avg Monthly Long Distance Charges':['mean','max'],
    
     'Longitude':['mean','sum','max','std']})
# Out:
#                 Age  Tenure in Months   Latitude  \
# mean      46.509726               NaN        NaN
# sum   327568.000000               NaN        NaN
# max             NaN              72.0  41.962127
# min             NaN               1.0  32.555828
# std             NaN               NaN        NaN
#
#       Avg Monthly Long Distance Charges      Longitude
# mean                          25.420517    -119.756684
# sum                                 NaN -843446.323117
# max                           49.990000    -114.192901
# min                                 NaN            NaN
# std                                 NaN       2.154425

# %%
#summarize categorically
print(df['Gender'].unique()) # display only unique values or categories
print(df['Gender'].nunique()) # display only unique numbers 
df['Gender'].value_counts() # display numbers categorically
df[['Gender','Married']].value_counts() # display numbers categorically (with multiple columns)
df[['City','Internet Type']].value_counts().reset_index() # this way index number got reset
# Out:
# ['Female' 'Male']
# 2
#                 City Internet Type  count
# 0          San Diego   Fiber Optic    163
# 1        Los Angeles   Fiber Optic    108
# 2        Los Angeles           DSL     77
# 3          San Diego           DSL     53
# 4      San Francisco   Fiber Optic     50
# ...              ...           ...    ...
# 2274      Blocksburg   Fiber Optic      1
# 2275         Ontario         Cable      1
# 2276      Blocksburg           DSL      1
# 2277  Olympic Valley           DSL      1
# 2278       Miramonte         Cable      1
#
# [2279 rows x 3 columns]
